# %% [markdown]
# <a href="https://colab.research.google.com/github/Fauzi455/PembelajaranMesin_2026/blob/main/TG1_244107020067_M%20FAUZI%20ROHMAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jedi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 66.2 MB/s eta 0:00:00
# ...

# %%
# !pip install pyprep

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install pyECG --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# PyPREP adalah library yang berfungsi untuk pembersihan data, seperti line-noise filtering, referencing, serta mendeteksi dan menginterpolasi saluran sinyal yang buruk atau rusak.
#
# SciPy adalah library yang digunakan untuk pemrosesan sinyal digital dasar, operasi aljabar linear, perhitungan statistik tingkat lanjut, dan transformasi Fourier.
#
# wandb adalah library untuk memantau dan melacak eksperimen machine learning. Digunakan untuk menyimpan log parameter pelatihan, memvisualisasikan grafik metrik (loss, akurasi) secara real-time ke dasbor web, serta mendokumentasikan model agar eksperimen mudah diulang dan dibandingkan.
#
# pyECG adalah library khusus untuk memproses dan menganalisis sinyal elektrokardiogram yang fungsinya meliputi pembacaan format file medis, deteksi peak (puncak gelombang QRS), ekstraksi fitur detak jantung, dan analisis Heart Rate Variability (HRV).

# %% [markdown]
# #BAGIAN 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
#     Jawab :
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
